# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Uh4FyaAU1EVvux91YQzf")
project = rf.workspace("xray-u9rf3").project("wsiroisimages")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 2.3 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.90, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to wsiroisImages-1 in yolov8:: 100%|██████████| 3767/3767 [00:00<00:00, 8965.48it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 17.6 MB/s eta 0:00:0000:01
# ...

# %%
# Read the updated text file
with open('/kaggle/working/wsiroisImages-1/data.yaml', 'r') as file:
    updated_content = file.read()

# Display the updated content
print(updated_content)
# Out:
# names:
# - lymphocytes and plasma cells
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: wsiroisimages
#   url: https://universe.roboflow.com/xray-u9rf3/wsiroisimages/dataset/1
#   version: 1
#   workspace: xray-u9rf3
# test: ../test/images
# train: wsiroisImages-1/train/images
# val: wsiroisImages-1/valid/images

# %%
# %%writefile /kaggle/working/wsiroisImages-1/data.yaml
# names:
# - lymphocyte
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: wsiroisimages
#   url: https://universe.roboflow.com/xray-u9rf3/wsiroisimages/dataset/1
#   version: 1
#   workspace: xray-u9rf3
# test:
# train: /kaggle/working/wsiroisImages-1/train
# val: /kaggle/working/wsiroisImages-1/valid
# Out:
# Overwriting /kaggle/working/wsiroisImages-1/data.yaml

# %%
# Read the updated text file
with open('/kaggle/working/wsiroisImages-1/data.yaml', 'r') as file:
    updated_content = file.read()

# Display the updated content
print(updated_content)
# Out:
# names:
# - lymphocyte
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: wsiroisimages
#   url: https://universe.roboflow.com/xray-u9rf3/wsiroisimages/dataset/1
#   version: 1
#   workspace: xray-u9rf3
# test:
# train: /kaggle/working/wsiroisImages-1/train
# val: /kaggle/working/wsiroisImages-1/valid

# %%
# !wandb disabled
# Out:
# W&B disabled.

# %%
from ultralytics import YOLO

# # Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# # Train the model with 2 GPUs
results = model.train(data="/kaggle/working/wsiroisImages-1/data.yaml", epochs=1000, imgsz=256, device=[0, 1], patience=20)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 101MB/s]
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                       CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# # Load a model
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

# # Train the model with 2 GPUs
results = model.train(data="/kaggle/working/wsiroisImages-1/data.yaml", epochs=1000, imgsz=256, device=[0, 1], patience=20, batch=32, workers=10)
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
#                                                       CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
import shutil
import os
from IPython.display import FileLink, display, HTML

def zip_folder(input_folder_path):
    # Define the name for the zip file
    zip_file_path = input_folder_path + '.zip'
    
    # Zip the folder
    shutil.make_archive(input_folder_path, 'zip', input_folder_path)
    
    # Check if the zip file is created successfully
    if os.path.exists(zip_file_path):
        print(f"Folder zipped successfully at: {zip_file_path}")
    else:
        print("Error in zipping the folder.")
    
    return zip_file_path

def create_download_link(zip_file_path):
    # Create a download link for the zip file
    display(HTML(f'<a href="{zip_file_path}" download>Click here to download {zip_file_path}</a>'))
    
    # JavaScript to automatically trigger the download
    display(HTML(f"""
        <script>
        var link = document.createElement('a');
        link.href = '{zip_file_path}';
        link.download = '{os.path.basename(zip_file_path)}';
        document.body.appendChild(link);
        link.click();
        document.body.removeChild(link);
        </script>
    """))

# Example usage
input_folder_path = '/kaggle/working/runs/detect/train'  # Replace with your folder path
zip_file_path = zip_folder(input_folder_path)

# Automatically trigger the download
create_download_link(zip_file_path)
# Out:
# Folder zipped successfully at: /kaggle/working/runs/detect/train.zip
# <a href="/kaggle/working/runs/detect/train.zip" download>Click here to download /kaggle/working/runs/detect/train.zip</a>
#         <script>
#         var link = document.createElement('a');
#         link.href = '/kaggle/working/runs/detect/train.zip';
#         link.download = 'train.zip';
#         document.body.appendChild(link);
#         link.click();
#         document.body.removeChild(link);
#         </script>
